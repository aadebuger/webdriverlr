# %%
from selenium import webdriver # 从selenium导入webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
from seleniumwire import webdriver
from selenium.webdriver.common.keys import Keys
import time
def custom(req, req_body, res, res_body):
    print(f'res_body length: {len(res_body)}')

options = {
    'custom_response_handler': custom
}
options1 = webdriver.ChromeOptions()
options1.add_argument('window-size=2000x600')
driver = webdriver.Chrome(seleniumwire_options=options,chrome_options=options1)  # Optional argument, if not specified will search path.
driver.get('http://ls5.ltools.cn/syslogin/login')

loginpath="""//*[@id="LoginName"]"""
elem = driver.find_element_by_xpath(loginpath)
elem.clear()
print("elem=",elem)
elem.send_keys("26519")
passpath="""//*[@id="password"]"""
elem = driver.find_element_by_xpath(passpath)
elem.clear()
print("elem=",elem)
elem.send_keys("654321")

loginpath="""//*[@id="loginValid"]"""
elem = driver.find_element_by_xpath(loginpath)
elem.click()

actionpath1="/html/body/div[2]/div[2]/div[3]/div[1]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div"
elem = driver.find_element_by_xpath(actionpath1)
elem.click()
time.sleep(10)
actionpath2="/html/body/div[2]/div[2]/div[1]/ul[2]/li[9]/a"
elem = driver.find_element_by_xpath(actionpath2)
elem.click()

time.sleep(10)
#actionpath3="""//*[@id="btnSaleTicket"]"""
actionpath4="""/html/body/div[2]/div[2]/div[3]/div[1]/form/div[1]/div[1]/div[2]/div/button"""


actionpath5="""/html/body/div[2]/div[2]/div[3]/div[1]/form/div[1]/div[1]/div[2]/div/ul/li[1]/a"""

actionpath6="""/html/body/div[2]/div[2]/div[3]/div[1]/div/div[2]/div/div/div/form/div[1]/div[2]/div[1]/div[2]/label[1]/i"""

actionpath7="""/html/body/div[2]/div[2]/div[3]/div[1]/div[2]/form/div[2]/div[3]/div[3]/div/table/tbody/tr[2]/td[4]"""


actionpath8="""/html/body/div[2]/div[2]/div[3]/div[1]/div[2]/form/div[2]/div[3]/div[3]/div/table/tbody/tr[2]/td[4]"""
#elem = driver.find_element_by_xpath(actionpath4)
#elem.click()
elem = driver.find_element_by_xpath("""//*[@id="search-nav"]""")
#actionname="新建单据"
#elem = driver.find_element_by_name(actionname)
#elem.click()
print("elem=",elem)

actionpath3="""//*[@id="btnSaleTicket"]"""
elem1 = driver.find_element_by_xpath(actionpath3)
print("elem=",elem1)
elem1.click()
elem2 = driver.find_element_by_xpath(actionpath4)
print("elem=",elem2)
elem2.click()

elem3 = driver.find_element_by_xpath(actionpath5)
print("elem=",elem3)
elem3.click()


time.sleep(10)
elem4 = driver.find_element_by_xpath(actionpath6)
print("elem=",elem4)
elem4.click()


time.sleep(10)
elem5 = driver.find_element_by_xpath("""//*[@id="customerName"]""")
print("elem5=",elem5)
elem5.send_keys("物美用友店")

elempath="""/html/body/div[2]/div[2]/div[3]/div[1]/div[2]/form/div[1]/div/div/div/div/div[4]/div/button[1]"""
elem6 = driver.find_element_by_xpath(elempath)
elem6.click()



time.sleep(10)

actionpath7="""/html/body/div[2]/div[2]/div[3]/div[1]/div[2]/form/div[2]/div[3]/div[3]/div/table/tbody/tr[2]/td[4]"""

elem7 = driver.find_element_by_xpath(actionpath7)
elem7.click()


actionpath8="""/html/body/div[2]/div[2]/div[3]/div[1]/div/div[2]/div/div/div/form/div[2]/div[2]/table/thead/tr/th[11]"""


time.sleep(10)
elem8 = driver.find_element_by_xpath(actionpath8)
elem8.click()


time.sleep(20)

elempath1="""/html/body/div[2]/div[2]/div[3]/div[1]/div/div[2]/div/div/div/form/div[2]/div[2]/table/tbody/tr/td[5]/input"""
elem9 = driver.find_element_by_xpath(elempath1)
print("elem9=",elem9)
#elem9.clear()

elem9.send_keys(Keys.BACKSPACE)
elem9.send_keys(100)


time.sleep(5)
actionpath10="""//*[@id="btnOk"]"""

elem10 = driver.find_element_by_xpath(actionpath10)
print("elem10=",elem10)
elem10.click()
# Out:
# res_body length: 13485
# res_body length: 1598
# res_body length: 4164
# res_body length: 5496
# res_body length: 3012
# res_body length: 31180
# res_body length: 33467
# res_body length: 1163
# res_body length: 110484
# elem= <selenium.webdriver.remote.webelement.WebElement (session="6af3e0f64fd8c7cd1a78e48cc0af00f9", element="8c1fee0f-b7af-4f71-974b-c510d08f8e83")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="6af3e0f64fd8c7cd1a78e48cc0af00f9", element="941c56a0-19fc-4a65-82f4-72d979ddb6a5")>
# res_body length: 12590
# res_body length: 127
# res_body length: 328590
# res_body length: 2738
# res_body length: 11069
# res_body length: 3191
# res_body length: 3698
# res_body length: 3421
# res_body length: 14369
# res_body length: 40703
# res_body length: 2630
# res_body length: 1881
# res_body length: 1412
# res_body length: 5469
# res_body length: 2428
# res_body length: 2141
# res_body length: 2797
# res_body length: 4843
# res_body length: 2240
# res_body length: 3051
# res_body length: 6073
# res_body length: 3012
# res_body length: 29400
# res_body length: 7781
# res_body length: 6532
# res_body length: 1190
# res_body length: 4357
# res_body length: 36940
# res_body length: 11571
# res_body length: 1694
# res_body length: 10785
# res_body length: 7331
# res_body length: 1667
# res_body length: 3831
# res_body length: 5417
# res_body length: 5035
# res_body length: 12723
# res_body length: 2746
# res_body length: 12741
# res_body length: 9104
# res_body length: 1180res_body length: 6960
#
# res_body length: 2781
# res_body length: 1890
# res_body length: 6410
# res_body length: 6071
# res_body length: 3149
# res_body length: 3370
# res_body length: 13485
# res_body length: 2747
# res_body length: 10985
# res_body length: 3250
# res_body length: 56691
# res_body length: 2135
# res_body length: 2232
# res_body length: 8780
# res_body length: 1741
# res_body length: 2064
# res_body length: 3164
# res_body length: 12940
# res_body length: 9419
# res_body length: 4610
# res_body length: 4469
# res_body length: 12412
# res_body length: 30581
# res_body length: 3819
# res_body length: 1190
# res_body length: 4414
# res_body length: 1203
# res_body length: 7328
# res_body length: 6479
# res_body length: 5730
# res_body length: 6577
# res_body length: 6993
# res_body length: 5910
# res_body length: 3418
# res_body length: 22995
# res_body length: 5392
# res_body length: 6197
# res_body length: 7444
# res_body length: 100401
# res_body length: 85
# res_body length: 788
# res_body length: 1425
# res_body length: 1163
# res_body length: 6203
# res_body length: 35740
# res_body length: 216099
# res_body length: 178
# res_body length: 326
# res_body length: 19
# res_body length: 110484
# res_body length: 2876
# res_body length: 5187
# res_body length: 85
# res_body length: 41292
# res_body length: 12275
# res_body length: 12275
# res_body length: 6552
# res_body length: 151
# res_body length: 91
# res_body length: 19186
# res_body length: 35939
# res_body length: 37
# res_body length: 84
# res_body length: 1638
# res_body length: 598
# res_body length: 476
# res_body length: 1252
# res_body length: 2083
# res_body length: 7816
# res_body length: 391
# res_body length: 688
# res_body length: 50315
# res_body length: 160
# res_body length: 67562
# res_body length: 39288
# res_body length: 24284
# res_body length: 23877
# res_body length: 11280
# res_body length: 15435
# res_body length: 46445
# res_body length: 16163
# res_body length: 20988
# res_body length: 14912
# res_body length: 37830
# res_body length: 30938
# res_body length: 22520
# res_body length: 35656
# res_body length: 36320
# res_body length: 35990
# res_body length: 35649
# res_body length: 71
# res_body length: 32
# res_body length: 25
# res_body length: 89
# res_body length: 160
# res_body length: 37
# res_body length: 32718
# res_body length: 2150
# res_body length: 3385
# res_body length: 6627
# res_body length: 1644
# res_body length: 4
# res_body length: 4
# res_body length: 4
# res_body length: 4
# res_body length: 42
# res_body length: 42
# res_body length: 42
# res_body length: 4
# res_body length: 4
# res_body length: 42
# res_body length: 7288
# res_body length: 4
# res_body length: 8178
# res_body length: 951
# elem= <selenium.webdriver.remote.webelement.WebElement (session="6af3e0f64fd8c7cd1a78e48cc0af00f9", element="34230cba-eea6-43c8-99e6-02e783276080")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="6af3e0f64fd8c7cd1a78e48cc0af00f9", element="1a768cfe-b862-4be5-ae2e-684bac2412e5")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="6af3e0f64fd8c7cd1a78e48cc0af00f9", element="53c343b4-f8a5-4013-946b-17f3d50f4a5f")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="6af3e0f64fd8c7cd1a78e48cc0af00f9", element="5092806a-5cb2-4057-8661-d65d24e22308")>
# res_body length: 19662
# res_body length: 2669
# res_body length: 2698
# res_body length: 1035
# res_body length: 2745
# res_body length: 3385
# res_body length: 7404
# res_body length: 38772
# res_body length: 150
# res_body length: 936
# res_body length: 89
# res_body length: 7138
# res_body length: 6892
# res_body length: 67562
# elem= <selenium.webdriver.remote.webelement.WebElement (session="6af3e0f64fd8c7cd1a78e48cc0af00f9", element="2495f887-b1d7-4656-9641-d6ee72c0e74c")>
# res_body length: 22618
# res_body length: 804
# res_body length: 4998
# res_body length: 1659
# res_body length: 3385
# res_body length: 2698
# res_body length: 5403
# res_body length: 4
# res_body length: 872
# res_body length: 67562
# res_body length: 4382
# res_body length: 1644
# res_body length: 2125
# res_body length: 67562
# elem5= <selenium.webdriver.remote.webelement.WebElement (session="6af3e0f64fd8c7cd1a78e48cc0af00f9", element="57d1603e-9fec-41ad-8b46-dbad46b1600c")>
# res_body length: 4
# res_body length: 1131
# res_body length: 89
# res_body length: 3300
# res_body length: 509
# res_body length: 9555
# res_body length: 171
# res_body length: 602
# res_body length: 60478
# res_body length: 171
# res_body length: 566
# res_body length: 20569
# res_body length: 2
# res_body length: 170
# res_body length: 557
# res_body length: 113772
# res_body length: 169
# res_body length: 89
# res_body length: 48
# res_body length: 570
# res_body length: 45489
# res_body length: 171
# res_body length: 6222
# res_body length: 4217
# res_body length: 621
# res_body length: 11254
# res_body length: 4
# res_body length: 12275
# res_body length: 3097
# res_body length: 7119
# res_body length: 171
# res_body length: 544
# res_body length: 5503
# res_body length: 508
# res_body length: 171
# res_body length: 2061
# res_body length: 543
# res_body length: 5406
# res_body length: 170
# res_body length: 594
# res_body length: 2920
# res_body length: 171
# res_body length: 2060
# res_body length: 89
# res_body length: 562
# res_body length: 6760942
# res_body length: 505
# res_body length: 394133
# res_body length: 170
# elem9= <selenium.webdriver.remote.webelement.WebElement (session="6af3e0f64fd8c7cd1a78e48cc0af00f9", element="b5a87a1e-767c-4472-a4be-5972cabb3693")>
# res_body length: 171
# res_body length: 542
# res_body length: 88250
# res_body length: 171
# res_body length: 518
# res_body length: 3835
# res_body length: 170
# res_body length: 89
# elem10= <selenium.webdriver.remote.webelement.WebElement (session="6af3e0f64fd8c7cd1a78e48cc0af00f9", element="480e4bd5-215c-423d-971e-72a78c7fc038")>
# res_body length: 615
# res_body length: 149
# res_body length: 77367
# res_body length: 18
# res_body length: 8194
# res_body length: 172
# res_body length: 2060
# res_body length: 601
# res_body length: 25441
# res_body length: 172
# res_body length: 2124
# res_body length: 90
# res_body length: 48
# res_body length: 2060
# res_body length: 89
# res_body length: 90
# res_body length: 2060
# res_body length: 2124
