# %%
from selenium import webdriver # 从selenium导入webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException
#from seleniumwire import webdriver
from selenium.webdriver.common.keys import Keys
import time

driver = initdriver()

job1(driver)
driver.quit()  
#请填写登录密码
# Out:
# /Users/aadebuger/GEXT/seleniumvenv3/lib/python3.6/site-packages/ipykernel_launcher.py:195: DeprecationWarning: use options instead of chrome_options
# elem= <selenium.webdriver.remote.webelement.WebElement (session="cfc8fcc65b8f8e2d5066331dc08338d2", element="fb0b45a5-2fa2-40c2-813e-24c30556aa64")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="cfc8fcc65b8f8e2d5066331dc08338d2", element="fd10f3bf-3557-402d-84c8-1fb090c4e2fa")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="cfc8fcc65b8f8e2d5066331dc08338d2", element="ea93ab04-e6e6-45d1-846a-e6b0d1ec8710")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="cfc8fcc65b8f8e2d5066331dc08338d2", element="129476ad-4802-4d03-abc9-a7ad31b63fdd")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="cfc8fcc65b8f8e2d5066331dc08338d2", element="f6ea0bcd-b962-40d1-b921-d64af217a0e1")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="cfc8fcc65b8f8e2d5066331dc08338d2", element="55c44267-135f-41f3-aa45-a327f76ddaa9")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="cfc8fcc65b8f8e2d5066331dc08338d2", element="cfc00fe4-9ceb-41a3-bb76-77b7310bd57c")>
# elem5= <selenium.webdriver.remote.webelement.WebElement (session="cfc8fcc65b8f8e2d5066331dc08338d2", element="5359761b-d3d7-4d6c-9216-abb2221bc6d1")>
# elem5= <selenium.webdriver.remote.webelement.WebElement (session="cfc8fcc65b8f8e2d5066331dc08338d2", element="6fb11c26-136c-44c8-aec6-8ea58d323626")>
# elem8= <selenium.webdriver.remote.webelement.WebElement (session="cfc8fcc65b8f8e2d5066331dc08338d2", element="e22a37b2-e792-4035-8712-9d9eec04552b")>
# elem9= <selenium.webdriver.remote.webelement.WebElement (session="cfc8fcc65b8f8e2d5066331dc08338d2", element="caabf3ee-d2e0-4fd4-8491-7e9c867cc011")>
# elem10= <selenium.webdriver.remote.webelement.WebElement (session="cfc8fcc65b8f8e2d5066331dc08338d2", element="28f446a2-b76d-4175-80fa-dd65e30be3e9")>
# alert text 没有选择审批人，提交后将无法再修改，请确认提交单据吗？
# alert text 单据提交成功!

# %%
def checkLogout():
#//*[@id="loginheader"]
    try:
        elem = driver.find_element_by_xpath("""//*[@id="loginheader"]""")
        print("login",elem)
    except:
        print("except ")
        
def login():
    loginpath="""//*[@id="LoginName"]"""
    elem = driver.find_element_by_xpath(loginpath)
    elem.clear()
    print("elem=",elem)
    elem.send_keys("26519")
    passpath="""//*[@id="password"]"""
    elem = driver.find_element_by_xpath(passpath)
    elem.clear()
    print("elem=",elem)
    elem.send_keys("654321")
    loginpath="""//*[@id="loginValid"]"""
    loginheader="""//*[@id="loginheader"]"""
    elem = driver.find_element_by_xpath(loginpath)
    elem.click()
def page1():
    try:
        actionpath1="/html/body/div[2]/div[2]/div[3]/div[1]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div"
        elem = driver.find_element_by_xpath(actionpath1)
        elem.click()
    except NoSuchElementException:  #spelling error making this code not work as expected
        print("NoSuch")
        elem = driver.find_element_by_xpath("""//*[@id="loginheader"]""")
        print("elem=",elem)
        print("elem text=",elem.text)
        if elem.text=="""登录帐号已在其他地方登录""":
            elem = driver.find_element_by_xpath(loginpath)
            elem.click()
            time.sleep(5)
        actionpath1="/html/body/div[2]/div[2]/div[3]/div[1]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div"
        elem = driver.find_element_by_xpath(actionpath1)
        elem.click()

def page2():
    actionpath2="/html/body/div[2]/div[2]/div[1]/ul[2]/li[9]/a"
    elem = driver.find_element_by_xpath(actionpath2)
    elem.click()
    time.sleep(10)
#actionpath3="""//*[@id="btnSaleTicket"]"""
    actionpath4="""/html/body/div[2]/div[2]/div[3]/div[1]/form/div[1]/div[1]/div[2]/div/button"""


    actionpath5="""/html/body/div[2]/div[2]/div[3]/div[1]/form/div[1]/div[1]/div[2]/div/ul/li[1]/a"""

    actionpath6="""/html/body/div[2]/div[2]/div[3]/div[1]/div/div[2]/div/div/div/form/div[1]/div[2]/div[1]/div[2]/label[1]/i"""

    actionpath7="""/html/body/div[2]/div[2]/div[3]/div[1]/div[2]/form/div[2]/div[3]/div[3]/div/table/tbody/tr[2]/td[4]"""


    actionpath8="""/html/body/div[2]/div[2]/div[3]/div[1]/div[2]/form/div[2]/div[3]/div[3]/div/table/tbody/tr[2]/td[4]"""
#elem = driver.find_element_by_xpath(actionpath4)
#elem.click()
    elem = driver.find_element_by_xpath("""//*[@id="search-nav"]""")
#actionname="新建单据"
#elem = driver.find_element_by_name(actionname)
#elem.click()
    print("elem=",elem)

    actionpath3="""//*[@id="btnSaleTicket"]"""
    elem1 = driver.find_element_by_xpath(actionpath3)
    print("elem=",elem1)
    elem1.click()
    elem2 = driver.find_element_by_xpath(actionpath4)
    print("elem=",elem2)
    elem2.click()

    elem3 = driver.find_element_by_xpath(actionpath5)
    print("elem=",elem3)
    elem3.click()
    time.sleep(5)
    elem4 = driver.find_element_by_xpath(actionpath6)
    print("elem=",elem4)
    elem4.click()

def search(name):
    elem5 = driver.find_element_by_xpath("""//*[@id="customerName"]""")
    print("elem5=",elem5)
    elem5.send_keys(name)

    elempath="""/html/body/div[2]/div[2]/div[3]/div[1]/div[2]/form/div[1]/div/div/div/div/div[4]/div/button[1]"""
    elem6 = driver.find_element_by_xpath(elempath)
    elem6.click()
    time.sleep(5)
    actionpath7="""/html/body/div[2]/div[2]/div[3]/div[1]/div[2]/form/div[2]/div[3]/div[3]/div/table/tbody/tr[2]/td[4]"""
    elem7 = driver.find_element_by_xpath(actionpath7)
    elem7.click()
    time.sleep(5)
    driver.switch_to.alert.accept()

def selectchanpin(name):
#//*[@id="jqg_table_SelCommodity_list_d256a71f-6d49-4b5b-8d7f-29769db780eb"]
    elem5 = driver.find_element_by_xpath("""//*[@id="commodityName"]""")
    print("elem5=",elem5)
    elem5.send_keys(name)

    elempath="""/html/body/div[2]/div[2]/div[3]/div[1]/div[2]/div[2]/div/div[1]/div/div/div/div/div[3]/div/button[1]"""
    elem6 = driver.find_element_by_xpath(elempath)
    elem6.click()
    time.sleep(5)
    actionpath7="""/html/body/div[2]/div[2]/div[3]/div[1]/div[2]/div[2]/div/div[2]/div[3]/div[3]/div/table/tbody/tr[2]/td[3]"""

    elem7 = driver.find_element_by_xpath(actionpath7)
    elem7.click()
    actionpath82="""/html/body/div[2]/div[2]/div[3]/div[1]/div[2]/div[2]/div/div[1]/div/div/div/div/div[3]/div/button[3]"""

    elem8 = driver.find_element_by_xpath(actionpath82)
    elem8.click()
    print("elem8=",elem8)
def selectchanpinamount(amt):
    elempath1="""/html/body/div[2]/div[2]/div[3]/div[1]/div/div[2]/div/div/div/form/div[2]/div[2]/table/tbody/tr/td[5]/input"""
    elem9 = driver.find_element_by_xpath(elempath1)
    print("elem9=",elem9)

    elem9.send_keys(Keys.BACKSPACE)
    elem9.send_keys(amt)

    
def xiaoshoudan(amt):
    search("长春经销商")



    actionpath8="""/html/body/div[2]/div[2]/div[3]/div[1]/div/div[2]/div/div/div/form/div[2]/div[2]/table/thead/tr/th[11]"""


    time.sleep(5)
    elem8 = driver.find_element_by_xpath(actionpath8)
    elem8.click()
    time.sleep(10)

    selectchanpin("文化石")
    time.sleep(5)

    selectchanpinamount(amt)

    time.sleep(5)
    actionpath10="""//*[@id="btnOk"]"""

    elem10 = driver.find_element_by_xpath(actionpath10)
    print("elem10=",elem10)
    elem10.click()

    time.sleep(5)
#driver.switchTo().alert().accept();
    a= driver.switch_to.alert
    print("alert text",a.text)
    prompt=a.text
    driver.switch_to.alert.accept()
    if prompt=="""没有选择审批人，提交后将无法再修改，请确认提交单据吗？""":
        time.sleep(10)
        print("alert text",a.text)
        driver.switch_to.alert.accept()
def job1(driver,amt):
    driver.get('http://ls5.ltools.cn/syslogin/login')

    login()
    time.sleep(5)
    page1()
    time.sleep(5)
    #page2


    page2()

    time.sleep(5)

    #elem5 = driver.find_element_by_xpath("""//*[@id="customerName"]""")
    #print("elem5=",elem5)
    #elem5.send_keys("物美用友店")

    #elempath="""/html/body/div[2]/div[2]/div[3]/div[1]/div[2]/form/div[1]/div/div/div/div/div[4]/div/button[1]"""
    #elem6 = driver.find_element_by_xpath(elempath)
    #elem6.click()
    #search("物美用友店")


    xiaoshoudan(amt)
    driver.quit()
def custom(req, req_body, res, res_body):
    print(f'res_body length: {len(res_body)}')

def initdriver():
    options = {
        'custom_response_handler': custom
    }
    options1 = webdriver.ChromeOptions()
    options1.add_argument('window-size=2000x600')
    #driver = webdriver.Chrome(seleniumwire_options=options,chrome_options=options1)  # Optional argument, if not specified will search path.
    driver = webdriver.Chrome(chrome_options=options1)  # Optional argument, if not specified will search path.
    driver.set_window_size(1400,1000)
    return driver

# %%
driver=initdriver()
# Out:
# /Users/aadebuger/GEXT/seleniumvenv3/lib/python3.6/site-packages/ipykernel_launcher.py:197: DeprecationWarning: use options instead of chrome_options

# %%
job1(driver)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-22195df38892> in <module>
# ----> 1 job1(driver)
#
# TypeError: job1() missing 1 required positional argument: 'amt'

# %%
from  datard import getnrows,filemonitor
import os

# %%
import os
downloaddir="/Users/aadebuger/GEXT/cloud2020/webdriverlr"
filemonitor( downloaddir)
filename=os.path.join(downloaddir,"应收总账.xlsx")
rows=getnrows(filename)
i=0
for item in rows:
    print(item)
    name,amt=item
    iamt =int(amt)
    print(name,iamt)
    if iamt ==0:
        iamt = 88
    driver=initdriver()
    job1(driver,iamt)
    i=i+1
    if i>2:
        break
# Out:
# [empty:'', text:'北京永丰路加盟店', empty:'', empty:'', number:68548.0, number:68548.0, empty:'', empty:'', number:68548.0, number:68548.0]
# text:'北京永丰路加盟店'
# 北京永丰路加盟店
# number:68548.0
# 68548.0
# 2
# 68548.0
# text:'北京永丰路加盟店'
# 北京永丰路加盟店
# number:68548.0
# 68548.0
# 2
# 68548.0
# [empty:'', text:'长春经销商', number:55000.0, number:55000.0, number:37378.5, number:37378.5, number:91000.0, number:91000.0, number:1378.5, number:1378.5]
# text:'长春经销商'
# 长春经销商
# number:37378.5
# 37378.5
# 2
# 37378.5
# text:'长春经销商'
# 长春经销商
# number:37378.5
# 37378.5
# 2
# 37378.5
# [empty:'', text:'东程商贸', number:67000.0, number:67000.0, number:50000.0, number:50000.0, number:279300.0, number:279300.0, number:-162300.0, number:-162300.0]
# text:'东程商贸'
# 东程商贸
# number:50000.0
# 50000.0
# 2
# 50000.0
# text:'东程商贸'
# 东程商贸
# number:50000.0
# 50000.0
# 2
# 50000.0
# [empty:'', text:'广州经销商', number:231000.0, number:231000.0, empty:'', empty:'', empty:'', empty:'', number:231000.0, number:231000.0]
# text:'广州经销商'
# 广州经销商
# empty:''
#
# 0
# text:'广州经销商'
# 广州经销商
# empty:''
#
# 0
# [empty:'', text:'吉天科技有限公司', empty:'', empty:'', empty:'', empty:'', number:500.0, number:500.0, number:-500.0, number:-500.0]
# text:'吉天科技有限公司'
# 吉天科技有限公司
# empty:''
#
# 0
# text:'吉天科技有限公司'
# 吉天科技有限公司
# empty:''
#
# 0
# [empty:'', text:'零售客户', empty:'', empty:'', number:523.72, number:523.72, number:2700.0, number:2700.0, number:-2176.28, number:-2176.28]
# text:'零售客户'
# 零售客户
# number:523.72
# 523.72
# 2
# 523.72
# text:'零售客户'
# 零售客户
# number:523.72
# 523.72
# 2
# 523.72
# [empty:'', text:'美廉美回龙观店', number:62108.0, number:62108.0, number:92650.0, number:92650.0, empty:'', empty:'', number:154758.0, number:154758.0]
# text:'美廉美回龙观店'
# 美廉美回龙观店
# number:92650.0
# 92650.0
# 2
# 92650.0
# text:'美廉美回龙观店'
# 美廉美回龙观店
# number:92650.0
# 92650.0
# 2
# 92650.0
# [empty:'', text:'南京经销商', number:110000.0, number:110000.0, number:1716588.0, number:1716588.0, empty:'', empty:'', number:1826588.0, number:1826588.0]
# text:'南京经销商'
# 南京经销商
# number:1716588.0
# 1716588.0
# 2
# 1716588.0
# text:'南京经销商'
# 南京经销商
# number:1716588.0
# 1716588.0
# 2
# 1716588.0
# [empty:'', text:'上海经销商', empty:'', empty:'', number:257191.2, number:257191.2, empty:'', empty:'', number:257191.2, number:257191.2]
# text:'上海经销商'
# 上海经销商
# number:257191.2
# 257191.2
# 2
# 257191.2
# text:'上海经销商'
# 上海经销商
# number:257191.2
# 257191.2
# 2
# 257191.2
# [empty:'', text:'世纪华联西北旺店', empty:'', empty:'', number:3790.0, number:3790.0, empty:'', empty:'', number:3790.0, number:3790.0]
# text:'世纪华联西北旺店'
# 世纪华联西北旺店
# number:3790.0
# 3790.0
# 2
# 3790.0
# text:'世纪华联西北旺店'
# 世纪华联西北旺店
# number:3790.0
# 3790.0
# 2
# 3790.0
# [empty:'', text:'物美用友店', number:12049.0, number:12049.0, empty:'', empty:'', empty:'', empty:'', number:12049.0, number:12049.0]
# text:'物美用友店'
# 物美用友店
# empty:''
#
# 0
# text:'物美用友店'
# 物美用友店
# empty:''
#
# 0
# [empty:'', text:'祥通物流公司', number:7000.0, number:7000.0, empty:'', empty:'', empty:'', empty:'', number:7000.0, number:7000.0]
# text:'祥通物流公司'
# 祥通物流公司
# empty:''
#
# 0
# text:'祥通物流公司'
# 祥通物流公司
# empty:''
#
# 0
# [empty:'', text:'永辉回龙观店', number:40000.0, number:40000.0, empty:'', empty:'', empty:'', empty:'', number:40000.0, number:40000.0]
# text:'永辉回龙观店'
# 永辉回龙观店
# empty:''
#
# 0
# text:'永辉回龙观店'
# 永辉回龙观店
# empty:''
#
# 0
# ('北京永丰路加盟店', 68548.0)
# 北京永丰路加盟店 68548
# /Users/aadebuger/GEXT/seleniumvenv3/lib/python3.6/site-packages/ipykernel_launcher.py:197: DeprecationWarning: use options instead of chrome_options
# elem= <selenium.webdriver.remote.webelement.WebElement (session="6a9ff2ae49f291fd548ae1890997e1d4", element="608bb85c-26c8-4ec1-b129-f5dd54e01aea")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="6a9ff2ae49f291fd548ae1890997e1d4", element="5d64e30b-9631-4b4a-af5d-fcecb6188036")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="6a9ff2ae49f291fd548ae1890997e1d4", element="68bb6848-e968-4605-97f7-cefc45cd0a8a")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="6a9ff2ae49f291fd548ae1890997e1d4", element="2d07a49e-073a-4f84-8439-789efa8996db")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="6a9ff2ae49f291fd548ae1890997e1d4", element="6e0693d0-d376-43a1-9429-05fe9f0cd54b")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="6a9ff2ae49f291fd548ae1890997e1d4", element="bbbd113f-6dfc-4281-ab9a-a116ec3f6600")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="6a9ff2ae49f291fd548ae1890997e1d4", element="0b9c861a-9aa8-4371-8a90-0adabe15d848")>
# elem5= <selenium.webdriver.remote.webelement.WebElement (session="6a9ff2ae49f291fd548ae1890997e1d4", element="f818ded1-9ca1-4207-84e1-8d8694af5bae")>
# elem5= <selenium.webdriver.remote.webelement.WebElement (session="6a9ff2ae49f291fd548ae1890997e1d4", element="98d112d8-3d86-4794-ba8a-7847e0f8a1bb")>
# elem8= <selenium.webdriver.remote.webelement.WebElement (session="6a9ff2ae49f291fd548ae1890997e1d4", element="d8c93566-e629-4d2a-b5fe-f8d71b602f1e")>
# elem9= <selenium.webdriver.remote.webelement.WebElement (session="6a9ff2ae49f291fd548ae1890997e1d4", element="290ed061-d604-459d-97ed-a0e7f572cf81")>
# elem10= <selenium.webdriver.remote.webelement.WebElement (session="6a9ff2ae49f291fd548ae1890997e1d4", element="dce29d1c-be9f-4d91-b3df-0c5a36bac51e")>
# alert text 没有选择审批人，提交后将无法再修改，请确认提交单据吗？
# alert text 单据提交成功!
# ('长春经销商', 37378.5)
# 长春经销商 37378
# /Users/aadebuger/GEXT/seleniumvenv3/lib/python3.6/site-packages/ipykernel_launcher.py:197: DeprecationWarning: use options instead of chrome_options
# elem= <selenium.webdriver.remote.webelement.WebElement (session="b648b374bc218905e772d16232a50cbf", element="48336ffd-8822-43c2-8487-b4b733146068")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="b648b374bc218905e772d16232a50cbf", element="60742ac1-8c8c-478d-bbfe-5d48449381a7")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="b648b374bc218905e772d16232a50cbf", element="87794ae9-0b1b-482a-b5c9-a26af9195808")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="b648b374bc218905e772d16232a50cbf", element="979b2615-e924-4c72-aee0-294860155884")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="b648b374bc218905e772d16232a50cbf", element="f0e52dfa-b10e-477f-82e3-40b127b6c811")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="b648b374bc218905e772d16232a50cbf", element="7f8092ea-0da1-4cb9-b98a-3d33d3b89678")>
# elem= <selenium.webdriver.remote.webelement.WebElement (session="b648b374bc218905e772d16232a50cbf", element="fe61f688-9fa5-4771-96f9-fefa63b36141")>
# elem5= <selenium.webdriver.remote.webelement.WebElement (session="b648b374bc218905e772d16232a50cbf", element="44e6812c-6c13-4f51-a20b-97500e19ecbc")>
# elem5= <selenium.webdriver.remote.webelement.WebElement (session="b648b374bc218905e772d16232a50cbf", element="83683a61-67aa-4a3e-9c63-0cd4d7c3ef17")>
# elem8= <selenium.webdriver.remote.webelement.WebElement (session="b648b374bc218905e772d16232a50cbf", element="5ef05c3c-8eee-4c37-9508-aef94bd5280a")>
# elem9= <selenium.webdriver.remote.webelement.WebElement (session="b648b374bc218905e772d16232a50cbf", element="19b65d6b-205a-47dd-874a-773f7a0962ca")>
# elem10= <selenium.webdriver.remote.webelement.WebElement (session="b648b374bc218905e772d16232a50cbf", element="c0ca80e7-439d-4f5d-bde1-7d4ab2ce4e68")>
# alert text 没有选择审批人，提交后将无法再修改，请确认提交单据吗？
# ---------------------------------------------------------------------------
# NoAlertPresentException                   Traceback (most recent call last)
# <ipython-input-80-8f0506a69ec8> in <module>
#      13         iamt = 88
#      14     driver=initdriver()
# ---> 15     job1(driver,iamt)
#      16     i=i+1
#      17     if i>2:
#
# <ipython-input-77-244e8009f57d> in job1(driver, amt)
#     183
#     184
# --> 185     xiaoshoudan(amt)
#     186     driver.quit()
#     187 def custom(req, req_body, res, res_body):
#
# <ipython-input-77-244e8009f57d> in xiaoshoudan(amt)
#     157     if prompt=="""没有选择审批人，提交后将无法再修改，请确认提交单据吗？""":
#     158         time.sleep(5)
# --> 159         print("alert text",a.text)
#     160         driver.switch_to.alert.accept()
#     161 def job1(driver,amt):
#
# ~/GEXT/seleniumvenv3/lib/python3.6/site-packages/selenium/webdriver/common/alert.py in text(self)
#      65         """
#      66         if self.driver.w3c:
# ---> 67             return self.driver.execute(Command.W3C_GET_ALERT_TEXT)["value"]
#      68         else:
#      69             return self.driver.execute(Command.GET_ALERT_TEXT)["value"]
#
# ~/GEXT/seleniumvenv3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/GEXT/seleniumvenv3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoAlertPresentException: Message: no such alert
#   (Session info: chrome=92.0.4515.159)
